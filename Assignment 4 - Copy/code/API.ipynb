# %%
import requests

API_KEY = "3ecf1571406a258a3c5f2552353444a3"
CITY = "Tehran"
URL = "http://api.openweathermap.org/data/2.5/weather"

params = {
    "q": CITY,
    "appid": API_KEY,
    "units": "metric"
}

response = requests.get(URL, params=params)
data = response.json()

# Print response for debugging
print(data)

# Safely access keys
if response.status_code == 200:
    print("City:", data.get("name"))
    print("Temperature:", data["main"]["temp"])
    print("Humidity:", data["main"]["humidity"])
    print("Wind Speed:", data["wind"]["speed"])
    print("Description:", data["weather"][0]["description"])
else:
    print("Error:", data.get("message", "Unknown error"))
# Out:
# {'cod': 401, 'message': 'Invalid API key. Please see https://openweathermap.org/faq#error401 for more info.'}
# Error: Invalid API key. Please see https://openweathermap.org/faq#error401 for more info.

# %%
print(repr(API_KEY))  # should show exactly "d61f0c55902723ae955f4d8d53307a2f"
# Out:
# '3ecf1571406a258a3c5f2552353444a3'
